# %% [markdown]
# #### Task for today<br>
# Dataset https://archive.ics.uci.edu/ml/datasets/Bag+of+Words <br>
# Download last 5 txt files in data folder<br><br>
# Q1. Try to find out a count of each and every word in a respective file and list of tuples with word and its respective count <br>&emsp;&emsp;Ex: word abort has occured how many times in that file<br>
# &emsp;&emsp;Sample example: [('sudh', 6), ('kumar', 3)] <br>
# Q2. Try to perform a reduce operation to get a count of all the words starting with the same alphabet<br>
# &emsp;&emsp;Sample example: [('a', 6), ('b', 34), ......] <br>
# Q3. Try to filter out all the words from dataset<br>
# &emsp;&emsp;Sample example: .001.abstract = abstract<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&ensp;=.002 = delete<br>
# &emsp;&emsp;and wherever there is a number don't extract that<br>
# Q4. Create a tuple set of all the records available in all the five files and then sore it in sqlite DB.<br>
# &emsp;&emsp;Sample example: (aah, >=, 354, fdsf, wer)<br> &emsp;&emsp;**HINT: 1. Use zip function<br>&emsp;&emsp;&emsp;&emsp;&emsp;2. Use for loop over a list of tuples and insert it into DB<br>&emsp;&emsp;&emsp;&emsp;&emsp;3. list 1 is representing file no 1, list 2 is representing file no 2 and so on. Read out all the files and store it in a list.**

# %%
import os
import csv
import sqlite3
import re

# %% [markdown]
# #### Question 1

# %%
for file in os.listdir():
    if file.endswith('.txt'):
        db = sqlite3.connect(f'{file.split(".txt")[0]}.db')
        cursor = db.cursor()
        
        cursor.execute(f'CREATE TABLE IF NOT EXISTS words (words TEXT)')
        
        with open(file, encoding='utf-8') as f:
            reader = csv.reader(f)
            
            for word in reader:
                cursor.execute('INSERT INTO words VALUES (?)', (word[0],))
            
            db.commit()
    
        db.close()

# %%
for file in os.listdir():
    if file.startswith('vocab') and file.endswith('.db'):
        db = sqlite3.connect(file)
        cursor = db.cursor()
        
        cursor.execute('SELECT words, COUNT(*) FROM words GROUP BY words LIMIT 5')
        print(f'For database {file}: {cursor.fetchall()}')
        
        db.close()
# Out:
# For database vocab.enron.db: [('aaa', 1), ('aaas', 1), ('aactive', 1), ('aadvantage', 1), ('aaker', 1)]
# For database vocab.kos.db: [('aarp', 1), ('abandon', 1), ('abandoned', 1), ('abandoning', 1), ('abb', 1)]
# For database vocab.nips.db: [('a2i', 1), ('aaa', 1), ('aaai', 1), ('aapo', 1), ('aat', 1)]
# For database vocab.nytimes.db: [('aah', 1), ('aahed', 1), ('aaron', 1), ('aback', 1), ('abacus', 1)]
# For database vocab.pubmed.db: [('!kung', 1), ('#1', 1), ('#10', 1), ('#11', 1), ('#12', 1)]

# %% [markdown]
# #### Question 2

# %%
def regexp(expr, item):
    reg = re.compile(expr)
    return reg.search(item) is not None

for file in os.listdir():
    if file.startswith('vocab') and file.endswith('.db'):
        db = sqlite3.connect(file)
        db.create_function("REGEXP", 2, regexp)
        cursor = db.cursor()
        
        cursor.execute('SELECT SUBSTR(words, 1, 1) AS first_letter, COUNT(*) FROM words WHERE first_letter REGEXP "^[A-Za-z]" GROUP BY first_letter')
        print(f'For database {file}:') 
        print(f'{cursor.fetchall()}')
        
        db.close()
# Out:
# For database vocab.enron.db:
# [('a', 1800), ('b', 1557), ('c', 2611), ('d', 1664), ('e', 1404), ('f', 1160), ('g', 859), ('h', 1000), ('i', 1084), ('j', 377), ('k', 426), ('l', 989), ('m', 1648), ('n', 768), ('o', 685), ('p', 1945), ('q', 135), ('r', 1723), ('s', 2826), ('t', 1366), ('u', 562), ('v', 469), ('w', 805), ('x', 62), ('y', 111), ('z', 66)]
# For database vocab.kos.db:
# [('a', 492), ('b', 368), ('c', 666), ('d', 448), ('e', 294), ('f', 333), ('g', 195), ('h', 246), ('i', 269), ('j', 89), ('k', 70), ('l', 257), ('m', 344), ('n', 139), ('o', 175), ('p', 525), ('q', 30), ('r', 461), ('s', 742), ('t', 323), ('u', 105), ('v', 96), ('w', 205), ('y', 26), ('z', 8)]
# For database vocab.nips.db:
# [('a', 852), ('b', 513), ('c', 1173), ('d', 704), ('e', 588), ('f', 458), ('g', 352), ('h', 354), ('i', 710), ('j', 107), ('k', 184), ('l', 475), ('m', 769), ('n', 352), ('o', 321), ('p', 910), ('q', 71), ('r', 779), ('s', 1351), ('t', 587), ('u', 230), ('v', 230), ('w', 225), ('x', 27), ('y', 47), ('z', 50)]
# For database vocab.nytimes.db:
# [('a', 2613), ('b', 2525), ('c', 4320), ('d', 2784), ('e', 1992), ('f', 1939), ('g', 1387), ('h', 1571), ('i', 1860), ('j', 439), ('k', 313), ('l', 1349), ('m', 2394), ('n', 988), ('o', 1101), ('p', 3467), ('q', 202), ('r', 2758), ('s', 5021), ('t', 2165), ('u', 1276), ('v', 704), ('w', 1049), ('x', 21), ('y', 117), ('z', 58305)]
# For database vocab.pubmed.db:
# [('a', 10701), ('b', 5489), ('c', 12544), ('d', 6724), ('e', 5739), ('f', 4482), ('g', 4291), ('h', 6418), ('i', 6013), ('j', 556), ('k', 1429), ('l', 4727), ('m', 9086), ('n', 6879), ('o', 3341), ('p', 13302), ('q', 499), ('r', 5897), ('s', 10777), ('t', 7081), ('u', 2346), ('v', 2315), ('w', 1484), ('x', 363), ('y', 301), ('z', 411)]

# %% [markdown]
# #### Question 3

# %%
for file in os.listdir():
    if file.endswith('.txt'):
        with open(file, encoding='utf-8') as f:
            words = f.read().split()
            
            print(f'For file {file}:')
            matched_words = list(filter(lambda x: re.match('^[a-zA-Z]+$', x), words))
            print(matched_words[:10])
# Out:
# For file vocab.enron.txt:
# ['aaa', 'aaas', 'aactive', 'aadvantage', 'aaker', 'aap', 'aapg', 'aaron', 'aarp', 'aas']
# For file vocab.kos.txt:
# ['aarp', 'abandon', 'abandoned', 'abandoning', 'abb', 'abc', 'abcs', 'abdullah', 'ability', 'aboard']
# For file vocab.nips.txt:
# ['aaa', 'aaai', 'aapo', 'aat', 'aazhang', 'abandonment', 'abbott', 'abbreviated', 'abcde', 'abe']
# For file vocab.nytimes.txt:
# ['aah', 'aahed', 'aaron', 'aback', 'abacus', 'abajo', 'abalone', 'abandon', 'abandoned', 'abandoning']
# For file vocab.pubmed.txt:
# ['aa', 'aaa', 'aaaa', 'aaad', 'aaas', 'aab', 'aabb', 'aabr', 'aac', 'aacc']

# %% [markdown]
# #### Question 4

# %%
file_lists = []

for file in os.listdir():
    if file.endswith('.txt'):
        with open(file, encoding='utf-8') as f: 
            file_lists.append(f.read().split())
            
records = list(zip(*file_lists))

db = sqlite3.connect('concat.db')
cursor = db.cursor()

cursor.execute('''CREATE TABLE IF NOT EXISTS concat(
    file1 TEXT, 
    file2 TEXT,
    file3 TEXT,
    file4 TEXT,
    file5 TEXT
)''')

for record in records:
    cursor.execute('INSERT INTO concat VALUES(?, ?, ?, ?, ?)', record)
    
db.commit()

# %%
cursor.execute('SELECT * FROM concat')
cursor.fetchall()
# Out:
# [('aaa', 'aarp', 'a2i', 'aah', '>='),
#  ('aaas', 'abandon', 'aaa', 'aahed', '>>'),
#  ('aactive', 'abandoned', 'aaai', 'aaron', '>>>'),
#  ('aadvantage', 'abandoning', 'aapo', 'aback', '>/='),
#  ('aaker', 'abb', 'aat', 'abacus', '->'),
#  ('aap', 'abc', 'aazhang', 'abajo', '--'),
#  ('aapg', 'abcs', 'abandonment', 'abalone', '-->'),
#  ('aaron', 'abdullah', 'abbott', 'abandon', '-/-'),
#  ('aarp', 'ability', 'abbreviated', 'abandoned', '-/+'),
#  ('aas', 'aboard', 'abcde', 'abandoning', '/-'),
#  ('aau', 'abortion', 'abe', 'abandonment', '/+-'),
#  ('ab1890', 'abortions', 'abeles', 'abandono', '..'),
#  ('ab1x', 'abraham', 'abi', 'abarnard', '...'),
#  ('ab31x', 'abrams', 'abilistic', 'abashed', '+-'),
#  ('aba', 'abroad', 'abilities', 'abate', '+/'),
#  ('abacus', 'absence', 'ability', 'abated', '+/--'),
#  ('abag', 'absent', 'abl', 'abatement', '+/?'),
#  ('abalone', 'absentee', 'able', 'abating', '+/+'),
#  ('abandon', 'absolute', 'ables', 'abbey', '++'),
#  ('abandoned', 'absolutely', 'ablex', 'abbot', '+++'),
#  ('abandoning', 'abstain', 'ably', 'abbreviated', '=0'),
#  ('abandonment', 'absurd', 'abnormal', 'abbreviation', '>0'),
#  ('abate', 'abu', 'abort', 'abc', '-0'),
#  ('abated', 'abuse', 'abound', 'abcnew', '+/0'),
#  ('abb', 'abuses', 'abramowicz', 'abdicate', '0-'),
#  ('abbott', 'academy', 'abrash', 'abdicated', '0%'),
#  ('abbreviated', 'accent', 'abrupt', 'abdicating', '0+'),
#  ('abbreviation', 'accept', 'abruptly', 'abdication', '.00'),
#  ('abby', 'acceptable', 'abscissa', 'abdomen', '=.000'),
#  ('abc', 'acceptance', 'absence', 'abdominal', '.000'),
#  ('abcm', 'accepted', 'absent', 'abduct', '.000001'),
#  ('abdullah', 'accepting', 'absolute', 'abducted', '=0.0001'),
#  ('abe', 'access', 'absolutely', 'abductees', '.00001'),
#  ('abel', 'accident', 'absorb', 'abducting', '0.0001.abstract'),
#  ('aberdeen', 'accidentally', 'absorbed', 'abduction', '.00005'),
#  ('abernathy', 'accidents', 'absorbing', 'abductor', '=.0001'),
#  ('aberration', 'accomplish', 'absorption', 'aberrant', '=0.001'),
#  ('abeyance', 'accomplished', 'abstr', 'aberration', '.0001'),
#  ('abhay', 'accomplishment', 'abstract', 'abet', '0.001.abstract'),
#  ('abhyankar', 'account', 'abstracted', 'abetted', '=.0002'),
#  ('abide', 'accountability', 'abstraction', 'abetting', '.0002'),
#  ('abilene', 'accountable', 'abu', 'abeyance', '=.0003'),
#  ('abilities', 'accounting', 'abundances', 'abhor', '.0003'),
#  ('ability', 'accounts', 'aca', 'abhorred', '=.0004'),
#  ('abitibi', 'accuracy', 'acad', 'abhorrence', '.0004'),
#  ('able', 'accurate', 'academic', 'abhorrent', '=.0005'),
#  ('abn', 'accurately', 'academy', 'abide', '.0005'),
#  ('abnamro', 'accusations', 'acc', 'abided', '0.005.abstract'),
#  ('abnormal', 'accused', 'accelerate', 'abides', '=.0006'),
#  ('aboard', 'accusing', 'accelerated', 'abiding', '.0006'),
#  ('abolish', 'achieve', 'accelerating', 'abierto', '.0007'),
#  ('abolished', 'achieved', 'acceleration', 'abiertos', '.0008'),
#  ('abolishing', 'achievements', 'accelerator', 'abilities', '.0009'),
#  ('abortion', 'acknowledge', 'accent', 'ability', '000-dalton'),
#  ('abound', 'acknowledged', 'accept', 'abject', '000-fold'),
#  ('aboutface', 'aclu', 'acceptable', 'abjectly', '000-mr'),
#  ('aboveaverage', 'act', 'acceptably', 'ablation', '=.001'),
#  ('abovemarket', 'actblue', 'acceptance', 'ablaze', '=0.01'),
#  ('abovereferenced', 'acted', 'accepted', 'able', '.001'),
#  ('abraham', 'acting', 'accepting', 'ably', '.0015'),
#  ('abramson', 'action', 'acceptor', 'abnegation', '.001.abstract'),
#  ('abreast', 'actions', 'access', 'abnormal', '0.01.abstract'),
#  ('abroad', 'active', 'accessed', 'abnormalities', '=.002'),
#  ('abrogate', 'actively', 'accessible', 'abnormality', '=0.02'),
#  ('abrogating', 'activism', 'accessing', 'abnormally', '.002'),
#  ('abrupt', 'activist', 'accommodate', 'aboard', '.0025'),
#  ('abruptly', 'activists', 'accommodated', 'abode', '0.02.abstract'),
#  ('absence', 'activities', 'accomodate', 'abodes', '=.003'),
#  ('absences', 'activity', 'accompanied', 'abogado', '=0.03'),
#  ('absense', 'actor', 'accompanying', 'abogados', '.003'),
#  ('absent', 'acts', 'accomplish', 'abolish', '=.004'),
#  ('absentee', 'actual', 'accomplished', 'abolished', '.004'),
#  ('absolute', 'adam', 'accomplishes', 'abolishing', '=.005'),
#  ('absolutely', 'adams', 'accord', 'abolition', '=0.05'),
#  ('absorb', 'add', 'accordance', 'abolitionist', '>0.05'),
#  ('absorbed', 'added', 'according', 'abominable', '.005'),
#  ('absorbing', 'adding', 'account', 'abomination', '0.05.abstract'),
#  ('absorption', 'addition', 'accounted', 'aboriginal', '0.05m'),
#  ('abstain', 'additional', 'accounting', 'aborigines', '0.05-p'),
#  ('abstract', 'address', 'accu', 'abort', '=.006'),
#  ('absurd', 'addressed', 'accumulate', 'aborted', '.006'),
#  ('abt', 'addresses', 'accumulated', 'aborting', '=.007'),
#  ('abu', 'addressing', 'accumulates', 'abortion', '.007'),
#  ('abundance', 'adds', 'accumulating', 'abortionist', '=.008'),
#  ('abundant', 'adjust', 'accumulation', 'abortive', '.008'),
#  ('abundantly', 'adjusted', 'accumulator', 'abound', '=.009'),
#  ('abuse', 'adjustments', 'accuracies', 'abounded', '.009'),
#  ('abused', 'admin', 'accuracy', 'abounding', '=.01'),
#  ('abuses', 'administration', 'accurate', 'aboveboard', '=0.1'),
#  ('abusing', 'administrations', 'accurately', 'abraham', '>0.1'),
#  ('abusive', 'administrative', 'ace', 'abrasion', '-0.1%'),
#  ('abx', 'administrator', 'acetylcholine', 'abrasive', '.01'),
#  ('abx1', 'admire', 'ach', 'abrasiveness', '+/-0.1'),
#  ('abx2', 'admission', 'achievable', 'abrasives', '0.1-'),
#  ('aca', 'admit', 'achieve', 'abre', '.010'),
#  ('acacia', 'admits', 'achieved', 'abreast', '=.011'),
#  ('academia', 'admitted', 'achievement', 'abridge', '.011'),
#  ('academic', 'admitting', 'achieves', 'abridged', '=.012'),
#  ('academically', 'ado', 'achieving', 'abridging', '.012'),
#  ('academy', 'adopt', 'achr', 'abril', '=.013'),
#  ('acapulco', 'adopted', 'acid', 'abrio', '.013'),
#  ('acc', 'adopting', 'ackley', 'abrir', '=.014'),
#  ('accel', 'ads', 'acknowledge', 'abroad', '.014'),
#  ('accelerate', 'adult', 'acknowledged', 'abrogate', '=.015'),
#  ('accelerated', 'adults', 'acknowledgement', 'abrogated', '.015'),
#  ('accelerates', 'advance', 'acknowledges', 'abrogation', '0.15m'),
#  ('accelerating', 'advanced', 'acknowledgment', 'abrupt', '=.016'),
#  ('acceleration', 'advantage', 'acm', 'abruptly', '.016'),
#  ('accelerator', 'advantages', 'acous', 'abruptness', '=.017'),
#  ('accent', 'adventure', 'acoust', 'abscess', '.017'),
#  ('accenture', 'advertise', 'acoustic', 'absconded', '=.018'),
#  ('accept', 'advertisement', 'acoustical', 'absence', '.018'),
#  ('acceptable', 'advertisements', 'acoustically', 'absences', '=.019'),
#  ('acceptance', 'advertiser', 'acquire', 'absent', '.019'),
#  ('acceptances', 'advertisers', 'acquired', 'absentee', '.01.abstract'),
#  ('accepted', 'advertising', 'acquires', 'absenteeism', '0.1-fold'),
#  ('accepting', 'advice', 'acquiring', 'absentees', '0.1m'),
#  ('access', 'advised', 'acquisition', 'absentia', '0.1-ml'),
#  ('accessed', 'adviser', 'acrobot', 'absently', '0.1mm'),
#  ('accessibility', 'advisers', 'act', 'absolute', '0.1n'),
#  ('accessible', 'advisor', 'acta', 'absolutely', '=.02'),
#  ('accessing', 'advisory', 'acter', 'absolutes', '=0.2'),
#  ('accessories', 'advocacy', 'acteristic', 'absolution', '>0.2'),
#  ('accessory', 'advocate', 'acti', 'absolutism', '-0.2%'),
#  ('accident', 'advocates', 'acting', 'absolutist', '.02'),
#  ('accidental', 'affair', 'action', 'absoluto', '+/-0.2'),
#  ('accidentally', 'affairs', 'activ', 'absolve', '0.2-'),
#  ('acclaimed', 'affect', 'activa', 'absolved', '.020'),
#  ('accolades', 'affected', 'activate', 'absolves', '=.021'),
#  ('accommodate', 'affiliate', 'activated', 'absolving', '.021'),
#  ('accommodated', 'affiliated', 'activates', 'absorb', '=.022'),
#  ('accommodating', 'affiliates', 'activating', 'absorbed', '.022'),
#  ('accommodation', 'affiliation', 'activation', 'absorbent', '=.023'),
#  ('accomodate', 'afford', 'active', 'absorber', '.023'),
#  ('accomodation', 'afghan', 'actively', 'absorbing', '=.024'),
#  ('accompanied', 'afghanistan', 'activities', 'absorption', '.024'),
#  ('accompany', 'aflcio', 'activity', 'abstain', '=.025'),
#  ('accompanying', 'afraid', 'actor', 'abstained', '.025'),
#  ('accomplish', 'africa', 'actu', 'abstaining', '=.026'),
#  ('accomplished', 'african', 'actual', 'abstention', '.026'),
#  ('accomplishing', 'africanamerican', 'actually', 'abstinence', '=.027'),
#  ('accomplishment', 'afscme', 'actuator', 'abstinent', '.027'),
#  ('accord', 'aft', 'acuity', 'abstract', '=.028'),
#  ('accordance', 'aftermath', 'acute', 'abstracted', '.028'),
#  ('according', 'afternoon', 'acyclic', 'abstraction', '.029'),
#  ('accordion', 'afterward', 'adaboost', 'abstractly', '0.2-fold'),
#  ('account', 'age', 'adaline', 'abstruse', '0.2m'),
#  ('accountabilities', 'aged', 'adam', 'absurd', '0.2-mm'),
#  ('accountability', 'agencies', 'adap', 'absurdist', '=.03'),
#  ('accountable', 'agency', 'adapt', 'absurdities', '>0.3'),
#  ('accountant', 'agenda', 'adapta', 'absurdity', '-0.3%'),
#  ('accounted', 'agent', 'adaptability', 'absurdly', '.03'),
#  ('accounting', 'agents', 'adaptable', 'abu', '+/-0.3'),
#  ('accreditation', 'ages', 'adaptation', 'abundance', '0.3-'),
#  ('accredited', 'aggressive', 'adapted', 'abundant', '.030'),
#  ('accretion', 'aggressively', 'adapting', 'abundantly', '.031'),
#  ('accretive', 'agree', 'adaption', 'abuse', '.032'),
#  ('accross', 'agreed', 'adaptive', 'abused', '.033'),
#  ('accrual', 'agreement', 'adaptively', 'abuser', '.034'),
#  ('accrue', 'agreements', 'adaptivity', 'abuses', '=.035'),
#  ('accrued', 'agrees', 'adatron', 'abusing', '.035'),
#  ('accruing', 'agriculture', 'adauboost', 'abusive', '=.036'),
#  ('acct', 'ahead', 'adclus', 'abut', '.036'),
#  ('acctg', 'ahmad', 'add', 'abutment', '=.037'),
#  ('accum', 'ahmed', 'added', 'abutting', '.037'),
#  ('accumedia', 'ahnold', 'addemup', 'abuzz', '=.038'),
#  ('accumulate', 'aid', 'adder', 'abysmal', '.038'),
#  ('accumulated', 'aide', 'addi', 'abysmally', '=.039'),
#  ('accumulating', 'aided', 'adding', 'abyss', '.039'),
#  ('accumulation', 'aides', 'addison', 'acaba', '0.3-fold'),
#  ('accuracy', 'aim', 'addition', 'acacia', '=.04'),
#  ('accurate', 'aimed', 'additional', 'academe', '>0.4'),
#  ('accurately', 'aims', 'additionally', 'academia', '-0.4%'),
#  ('accured', 'aint', 'additive', 'academic', '.04'),
#  ('accusation', 'air', 'additively', 'academically', '+/-0.4'),
#  ('accuse', 'airborne', 'address', 'academician', '.040'),
#  ('accused', 'aircraft', 'addressable', 'academies', '.041'),
#  ('accuses', 'aired', 'addressed', 'academy', '.042'),
#  ('accusing', 'airing', 'addresses', 'acaso', '.043'),
#  ('accustomed', 'airplane', 'addressing', 'acc', '.044'),
#  ('ace', 'airport', 'ade', 'accede', '.045'),
#  ('acer', 'airwaves', 'adelaide', 'acceded', '=.046'),
#  ('aces', 'akin', 'adelson', 'acceding', '.046'),
#  ('acess', 'aksen', 'adequate', 'accelerant', '=.047'),
#  ('acevedo', 'alabama', 'adequately', 'accelerate', '.047'),
#  ('aceves', 'alan', 'adhesion', 'accelerated', '=.048'),
#  ('achievable', 'alarm', 'adiabatic', 'accelerates', '.048'),
#  ('achieve', 'alas', 'adjacency', 'accelerating', '=.049'),
#  ('achieved', 'alaska', 'adjacent', 'acceleration', '.049'),
#  ('achievement', 'albuquerque', 'adjectives', 'accelerator', '0.4-fold'),
#  ('achieves', 'alert', 'adjoint', 'accelerometer', '=.05'),
#  ('achieving', 'alerts', 'adjust', 'accent', '=0.5'),
#  ('achilles', 'alex', 'adjustable', 'accented', '>.05'),
#  ('acid', 'alexander', 'adjusted', 'accentuate', '>0.5'),
#  ('acidity', 'alexanders', 'adjusting', 'accentuated', '-0.5%'),
#  ('ackerman', 'alhusainy', 'adjustment', 'accentuates', '.05'),
#  ('acknowledge', 'ali', 'administration', 'accentuating', '+/-0.5'),
#  ('acknowledged', 'alice', 'admissibility', 'accept', '0.5-'),
#  ('acknowledgement', 'alienated', 'admissible', 'acceptability', '+/-0.50'),
#  ('acknowledges', 'alive', 'admission', 'acceptable', '.054'),
#  ('acknowledging', 'allawi', 'admit', 'acceptably', '.055'),
#  ('acknowledgment', 'allday', 'adopt', 'acceptance', '.056'),
#  ('acl', 'allegation', 'adopted', 'acceptances', '.057'),
#  ('aclu', 'allegations', 'adopting', 'accepted', '.05.abstract'),
#  ('acn', 'alleged', 'adrian', 'accepting', '0.5-cm'),
#  ('acorn', 'allegedly', 'adult', 'acceso', '0.5-fold'),
#  ('acoustic', 'allegiance', 'adv', 'access', '0.5-kb'),
#  ('acquaintance', 'allegory', 'advan', 'accessatlanta', '0.5m'),
#  ('acquaintances', 'allen', 'advance', 'accessed', '0.5-m'),
#  ('acquainted', 'alliance', 'advanced', 'accesses', '0.5-mg'),
#  ('acquire', 'alliances', 'advances', 'accessibility', '0.5-ml'),
#  ('acquired', 'allied', 'advantage', 'accessible', '0.5mm'),
#  ('acquirer', 'allies', 'advantageous', 'accessing', '0.5-mm'),
#  ('acquires', 'allimportant', 'advantages', 'accession', '0.5-t'),
#  ('acquiring', 'allowed', 'adversary', 'accessories', '0.5x'),
#  ('acquisition', 'allowing', 'adverse', 'accessorize', '=.06'),
#  ('acquistion', 'ally', 'advice', 'accessorized', '.06'),
#  ('acr', 'alongside', 'advocate', 'accessorizing', '+/-0.6'),
#  ('acre', 'alqaeda', 'advocated', 'accessory', '0.6-fold'),
#  ('acreage', 'alqaida', 'aea', 'accident', '0.6-kb'),
#  ('acrefeet', 'alsadr', 'aer', 'accidental', '0.6-mm'),
#  ('acres', 'alternative', 'aerial', 'accidentally', '=.07'),
#  ('acrobat', 'alternatives', 'aero', 'accidente', '-0.7%'),
#  ('acronym', 'altogether', 'aeronautic', 'accidently', '.07'),
#  ('acrosstheboard', 'altsite', 'aerospace', 'accion', '0.7-fold'),
#  ('act', 'alzheimers', 'aertsen', 'acciones', '0.7-kb'),
#  ('acta', 'amazing', 'affect', 'accionistas', '=.08'),
#  ('acted', 'amazingly', 'affected', 'acclaim', '>0.8'),
#  ('acteva', 'amazon', 'affecting', 'acclaimed', '-0.8%'),
#  ('actifund', 'ambassador', 'afferent', 'acclamation', '.08'),
#  ('acting', 'ambitions', 'affine', 'acclimate', '0.8-kb'),
#  ('action', 'ambitious', 'afford', 'acclimated', '=.09'),
#  ('actionable', 'ambush', 'afforded', 'accolade', '>0.9'),
#  ('activate', 'amdt', 'afosr', 'accolades', '.09'),
#  ('activated', 'amendment', 'africa', 'accommodate', '0.9-kb'),
#  ('activating', 'amendments', 'aftereffect', 'accommodated', '0-day'),
#  ('activation', 'america', 'afterward', 'accommodates', '0-h'),
#  ('active', 'american', 'against', 'accommodating', '0-i'),
#  ('activecom', 'americanled', 'agation', 'accommodation', '0m'),
#  ('actively', 'americans', 'agc', 'accomodate', '0-thalassemia'),
#  ('actives', 'americas', 'age', 'accompanied', '=1'),
#  ('activism', 'amid', 'aged', 'accompanies', '>1'),
#  ('activist', 'amidst', 'agencies', 'accompaniment', '>/=1'),
#  ('activites', 'ammo', 'agency', 'accompanist', '>1%'),
#  ('activities', 'ammunition', 'agent', 'accompany', '-1'),
#  ('activity', 'amount', 'ages', 'accompanying', '--1'),
#  ('acton', 'amounts', 'agglomerative', 'accompli', '-1%'),
#  ('actor', 'amp', 'aggregate', 'accomplice', '.1'),
#  ('actress', 'amphibians', 'aggregated', 'accomplices', '.1%'),
#  ('actual', 'ample', 'aggregating', 'accomplish', '$1'),
#  ('actually', 'analogy', 'aggregation', 'accomplished', '*1'),
#  ('actuarial', 'analyses', 'aggressive', 'accomplishes', '#1'),
#  ('acumen', 'analysis', 'aging', 'accomplishing', '+1'),
#  ('acute', 'analyst', 'agnostic', 'accomplishment', '+-1'),
#  ('acwa', 'analysts', 'ago', 'accord', '+/-1'),
#  ('ada', 'analyze', 'agonist', 'accordance', '+1%'),
#  ('adam', 'analyzed', 'agr', 'accorded', '1-'),
#  ('adamant', 'anchor', 'agree', 'according', '1/'),
#  ('adamantly', 'ancient', 'agreed', 'accordion', '1.'),
#  ('adamiak', 'andor', 'agreement', 'accordionist', '1%'),
#  ('adamson', 'andrea', 'agrees', 'accost', '1+'),
#  ('adante', 'andrew', 'agrin', 'accosted', '=10'),
#  ('adapt', 'andy', 'aha', 'account', '=.10'),
#  ('adaptable', 'anecdotal', 'ahc', 'accountability', '=1.0'),
#  ('adaptation', 'anemic', 'ahd', 'accountable', '=10%'),
#  ('adapted', 'anew', 'ahead', 'accountancy', '>10'),
#  ('adapter', 'angeles', 'ahmad', 'accountant', '>/=10'),
#  ('adaptive', 'anger', 'ahp', 'accounted', '>1.0'),
#  ('adaptiveinfo', 'angered', 'aic', 'accounting', '>10%'),
#  ('adaytum', 'angry', 'aid', 'accouterment', '-1.0%'),
#  ('adc', 'angst', 'aifnn', 'accoutrement', '-10%'),
#  ('add', 'ann', 'aii', 'accredit', '.10'),
#  ('addai', 'annenberg', 'aij', 'accreditation', '$10'),
#  ('adddrop', 'anniversary', 'aim', 'accredited', '*10'),
#  ('added', 'announce', 'aimed', 'accrediting', '#10'),
#  ('addedvalue', 'announced', 'aiming', 'accretion', '+/-10'),
#  ('addendum', 'announcement', 'ain', 'accretive', '+/-1.0'),
#  ('adder', 'announces', 'aining', 'accrue', '+/-10%'),
#  ('addict', 'announcing', 'aip', 'accrued', '+10%'),
#  ('addictive', 'annoying', 'air', 'accrues', '1.0-'),
#  ('addin', 'annual', 'airborne', 'accruing', '10-'),
#  ('adding', 'anonymity', 'aircraft', 'accumulate', '10+'),
#  ('addison', 'anonymous', 'aisb', 'accumulated', '=100'),
#  ('addition', 'answer', 'ait', 'accumulates', '>100'),
#  ('additional', 'answered', 'aixi', 'accumulating', '>/=100'),
#  ('additionally', 'answering', 'aji', 'accumulation', '>100%'),
#  ('additive', 'answers', 'akaike', 'accuracy', '$100'),
#  ('addon', 'anthony', 'aker', 'accurate', '+/-1.00'),
#  ('address', 'antiabortion', 'akin', 'accurately', '+100%'),
#  ('addressed', 'antiamerican', 'ala', 'accursed', '100-'),
#  ('addressee', 'antibush', 'alamitos', 'accusation', '>1000'),
#  ('addressees', 'anticipated', 'alamos', 'accusatory', '>1,000'),
#  ('addresses', 'antidean', 'alan', 'accuse', '1000-'),
#  ('addressing', 'antigay', 'alarm', 'accused', '>10,000'),
#  ('addtion', 'antikerry', 'albeit', 'accuser', '$10,000'),
#  ('addtional', 'antiwar', 'albrecht', 'accuses', '>100,000'),
#  ('adea', 'anxiety', 'albright', 'accusing', '$100,000'),
#  ('adelson', 'anymore', 'albuquerque', 'accustomed', '100,000-fold'),
#  ('adept', 'anytime', 'albus', 'ace', '100,000g'),
#  ('adeq', 'apologies', 'alc', 'aced', '100,000/microl'),
#  ('adequacy', 'apologists', 'alcove', 'aceptar', '10,000-fold'),
#  ('adequate', 'apologize', 'alent', 'acepto', '10,000/microl'),
#  ('adequately', 'apology', 'alert', 'acerbic', '>1000-fold'),
#  ('ader', 'appalling', 'alertness', 'acerca', '1,000-fold'),
#  ('adewumi', 'apparatus', 'alessandro', 'acero', '1000-fold'),
#  ('adexa', 'apparent', 'alex', 'aces', '1000-hz'),
#  ('adhere', 'apparently', 'alexander', 'acetaminophen', '1,000/microl'),
#  ('adherence', 'appeal', 'alexandre', 'acetate', '100-1000-fold'),
#  ('adhering', 'appealed', 'alfred', 'acetic', '100-bp'),
#  ('adhoc', 'appealing', 'alg', 'acetone', '100-day'),
#  ('adi', 'appeals', 'algebra', 'acetylcholine', '100-day-old'),
#  ('aditya', 'appearance', 'algebraic', 'ache', '>100-fold'),
#  ('adjacent', 'appearances', 'algebraically', 'ached', '100-fold'),
#  ('adjoining', 'appeared', 'algo', 'aches', '100g'),
#  ('adjourn', 'appearing', 'algorit', 'achievable', '100-g'),
#  ('adjourned', 'appears', 'algorithm', 'achieve', '100-hue'),
#  ('adjournment', 'applause', 'algorithmic', 'achieved', '100-hz'),
#  ('adjudicate', 'apple', 'ali', 'achievement', '100k'),
#  ('adjudication', 'apples', 'aliased', 'achiever', '100-kb'),
#  ('adjunct', 'application', 'aliasing', 'achieves', '100-kd'),
#  ('adjust', 'applications', 'align', 'achieving', '100-kda'),
#  ('adjustable', 'applied', 'aligned', 'aching', '100-m'),
#  ('adjusted', 'applies', 'aligning', 'achingly', '100mg'),
#  ('adjusting', 'apply', 'alignment', 'achy', '100_mg'),
#  ('adjustment', 'appointed', 'alike', 'acid', '100-mg'),
#  ('adl', 'appointment', 'alization', 'acidic', '100mg/kg'),
#  ('adler', 'appreciated', 'alkon', 'acidity', '100-microgram'),
#  ('adm', 'appreciation', 'allel', 'acidly', '100-microl'),
#  ('admin', 'approach', 'allen', 'acknowledge', '100/microl'),
#  ('administer', 'approached', 'alleviate', 'acknowledged', '100-microliter'),
#  ('administered',
#   'approaches',
#   'allinson',
#   'acknowledgement',
#   '100/microliter'),
#  ('administering', 'approaching', 'allman', 'acknowledges', '100_microm'),
#  ('administration',
#   'appropriations',
#   'allocate',
#   'acknowledging',
#   '100-microm'),
#  ('administrative', 'approval', 'allocated', 'acknowledgment', '100-micron'),
#  ('administratively', 'approve', 'allocates', 'acknowleged', '100-min'),
#  ('administrator', 'approved', 'allocating', 'acme', '100/min'),
#  ('adminstration', 'approximately', 'allocation', 'acne', '100-ml'),
#  ('admirable', 'apr', 'allocator', 'acolyte', '100mm'),
#  ('admiral', 'april', 'allow', 'acolytes', '100-mm'),
#  ('admiration', 'aps', 'allowable', 'acompanadas', '100nm'),
#  ('admire', 'apt', 'allowed', 'acorn', '100-nm'),
#  ('admired', 'arab', 'allowing', 'acoustic', '100-point'),
#  ('admirer', 'arabia', 'ally', 'acoustical', '100s'),
#  ('admission', 'arabic', 'alm', 'acoustically', '100th'),
#  ('admit', 'arabs', 'almaden', 'acquaint', '100-times'),
#  ('admitted', 'arafat', 'almeida', 'acquaintance', '100x'),
#  ('admittedly', 'architect', 'alon', 'acquaintances', '10-100-fold'),
#  ('admitting', 'archives', 'aloud', 'acquainted', '10-10m'),
#  ('admonished', 'archpundit', 'alpha', 'acquiesce', '10,11-epoxide'),
#  ('admonition', 'arctic', 'alphabet', 'acquiesced', '10-11m'),
#  ('adobe', 'area', 'alphanumeric', 'acquiescence', '1012/l'),
#  ('adolph', 'areas', 'alphas', 'acquiescing', '10-12m'),
#  ('adopt', 'arena', 'alspector', 'acquire', '10-15-fold'),
#  ('adopted', 'arent', 'alt', 'acquired', '10-20-fold'),
#  ('adopter', 'arg', 'alter', 'acquirer', '102-fold'),
#  ('adopting', 'argue', 'alteration', 'acquires', '10-2m'),
#  ('adoption', 'argued', 'altered', 'acquiring', '103-fold'),
#  ('adorable', 'argues', 'altering', 'acquisition', '103-hgr'),
#  ('adore', 'arguing', 'alterna', 'acquisitive', '10-3m'),
#  ('adr', 'argument', 'alternate', 'acquistion', '103/microl'),
#  ('adrian', 'arguments', 'alternately', 'acquit', '103/microliter'),
#  ('adrienne', 'ari', 'alternates', 'acquittal', '103/ml'),
#  ('adsl', 'aristide', 'alternating', 'acquitted', '103pd'),
#  ('adtran', 'arizona', 'alternation', 'acquitting', '104e'),
#  ('adult', 'arkansas', 'alternative', 'acre', '104-fold'),
#  ('advance', 'arlen', 'alternatively', 'acreage', '104/kg'),
#  ('advanced', 'arlington', 'alternatives', 'acres', '10-4m'),
#  ('advancement', 'arm', 'altitude', 'acrid', '104/microliter'),
#  ('advancer', 'armed', 'alto', 'acrimonious', '104/ml'),
#  ('advances', 'armitage', 'altogether', 'acrimony', '>105'),
#  ('advancing', 'armor', 'altos', 'acrobat', '105-fold'),
#  ('advani', 'armored', 'alvinn', 'acrobatic', '105-kda'),
#  ('advanta', 'arms', 'alvis', 'acronym', '105/kg'),
#  ('advantage', 'armstrong', 'alway', 'acrylamide', '10-5m'),
#  ('advantageous', 'army', 'alzheimer', 'acrylic', '105/ml'),
#  ('advantages', 'armys', 'amacrine', 'act', '>106'),
#  ('advent', 'arnold', 'amap', 'acted', '1064-nm'),
#  ('adventure', 'arrest', 'amari', 'acting', '106-fold'),
#  ('adventures', 'arrested', 'amax', 'action', '106/g'),
#  ('adversarial', 'arrests', 'ambient', 'actionable', '106/kg'),
#  ('adversaries', 'arrive', 'ambiguities', 'actitud', '106/l'),
#  ('adverse', 'arrived', 'ambiguity', 'activate', '10-6m'),
#  ('adversely', 'arrives', 'ambiguous', 'activated', '106/ml'),
#  ('adversity', 'arrogance', 'amenable', 'activates', '106ru'),
#  ('advertise', 'arrogant', 'amer', 'activating', '107/kg'),
#  ('advertised', 'art', 'america', 'activation', '10-7m'),
#  ('advertisement', 'article', 'american', 'activator', '10-7_m'),
#  ('advertiser', 'articles', 'americana', 'active', '107/ml'),
#  ('advertises', 'articulate', 'ames', 'actively', '108/kg'),
#  ('advertising', 'artillery', 'amherst', 'activewear', '10-8m'),
#  ('advice', 'asap', 'amin', 'actividad', '108/ml'),
#  ('advice_____________________',
#   'ashamed',
#   'aminergic',
#   'actividades',
#   '109203x'),
#  ('advisable', 'ashcroft', 'amino', 'activism', '109cd'),
#  ('advise', 'ashcrofts', 'amir', 'activist', '109cd2+'),
#  ('advised', 'asia', 'amit', 'activites', '109/l'),
#  ('adviser', 'asian', 'amnesia', 'activities', '109/liter'),
#  ('advises', 'asked', 'amorphous', 'activity', '10-9m'),
#  ('advising', 'asks', 'amount', 'activos', '109/ml'),
#  ('advisor', 'aspect', 'ampa', 'acto', '10a'),
#  ('advisory', 'aspects', 'ample', 'actor', '10-amino'),
#  ('advocacy', 'aspirations', 'amples', 'actores', '10b'),
#  ('advocate', 'ass', 'ampli', 'actorly', '10-base'),
#  ('advocated', 'assassination', 'amplification', 'actos', '10-bp'),
#  ('advocates', 'assault', 'amplified', 'actress', '10c'),
#  ('advocating', 'assembled', 'amplifier', 'actresses', '10-cm'),
#  ('aea', 'assembly', 'amplifies', 'actriz', '10d'),
#  ('aec', 'asserted', 'amplify', 'actuacion', '10-d'),
#  ('aeco', 'assertion', 'amplifying', 'actual', '10_day'),
#  ('aegean', 'assertions', 'amplitude', 'actuales', '10-day'),
#  ('aegis', 'asses', 'amplitudes', 'actualidad', '10-day-old'),
#  ('ael', 'assess', 'amputation', 'actuality', '10-d-old'),
#  ('aeneas', 'assessment', 'amsterdam', 'actualization', '10e'),
#  ('aep', 'assessments', 'ana', 'actually', '10-edam'),
#  ('aephpl', 'asset', 'anal', 'actualmente', '10f'),
#  ('aer', 'assets', 'analog', 'actuar', '>10-fold'),
#  ('aera', 'asshole', 'analogical', 'actuarial', '10-fold'),
#  ('aerial', 'assholes', 'analogies', 'actuaries', '10-formyltetrahydrofolate'),
#  ('aerobic', 'assigned', 'analogous', 'actuary', '10g'),
#  ('aeros', 'assignment', 'analogously', 'actuator', '10-g'),
#  ('aerospace', 'assist', 'analogue', 'acuerdo', '10/group'),
#  ('aes', 'assistance', 'analogy', 'acuerdos', '10-gy'),
#  ('aesop', 'assistant', 'analy', 'acuity', '10h'),
#  ('aess', 'associate', 'analyse', 'acumen', '10-h'),
#  ('aesthetic', 'associates', 'analysed', 'acupuncture', '10-hour'),
#  ('aet', 'association', 'analyser', 'acupuncturist', '10-hr'),
#  ('aether', 'assume', 'analyses', 'acute', '10-hz'),
#  ('aetna', 'assumed', 'analysing', 'acutely', '10-item'),
#  ('af56661', 'assumes', 'analysis', 'adage', '10k'),
#  ('afar', 'assuming', 'analyte', 'adagio', '1.0-kb'),
#  ('afb', 'assumption', 'analytic', 'adam', '10-kb'),
#  ('afc', 'assumptions', 'analytical', 'adamant', '10-kd'),
#  ('affair', 'assure', 'analytically', 'adamantly', '10-kda'),
#  ('affairsthe', 'assured', 'analyze', 'adapt', '10-km'),
#  ('affect', 'atlanta', 'analyzed', 'adaptability', '10l'),
#  ('affected', 'atlantic', 'analyzer', 'adaptable', '10m'),
#  ('affecting', 'atlarge', 'analyzes', 'adaptation', '10-m'),
#  ('affection', 'atomic', 'analyzing', 'adapted', '10-membered'),
#  ('affidavit', 'atrios', 'anand', 'adapter', '10-mer'),
#  ('affiliate', 'atrocities', 'anandan', 'adapting', '10mg'),
#  ('affiliated', 'attached', 'anastasio', 'adaption', '10-mg'),
#  ('affiliates', 'attack', 'anatomical', 'adaptive', '10_mg/kg'),
#  ('affiliation', 'attacked', 'anatomically', 'add', '10-mg/kg'),
#  ('affinity', 'attacking', 'anatomy', 'addam', '10mg/kg'),
#  ('affirm', 'attacks', 'ance', 'added', '10-mhz'),
#  ('affirmation', 'attempt', 'ances', 'addendum', '10-microgram'),
#  ('affirmative', 'attempted', 'ancestor', 'addict', '10-microl'),
#  ('affirmatively', 'attempting', 'ander', 'addicted', '10microm'),
#  ('affirmed', 'attempts', 'andersen', 'addicting', '10_microm'),
#  ('affirming', 'attend', 'anderson', 'addiction', '10-microm'),
#  ('afflicted', 'attendance', 'andre', 'addictive', '10-micron'),
#  ('affliction', 'attended', 'andreas', 'adding', '10min'),
#  ('affluent', 'attending', 'andreou', 'addition', '10_min'),
#  ('afford', 'attention', 'andrew', 'additional', '10-min'),
#  ('affordable', 'attitude', 'andy', 'additionally', '10-minus'),
#  ('afforded', 'attitudes', 'anention', 'additive', '10-minute'),
#  ('afghan', 'attorney', 'anesthetized', 'additives', '10-ml'),
#  ('afghanistan', 'attorneys', 'angeles', 'addled', '10mm'),
#  ('afl', 'attract', 'angeline', 'address', '1.0-mm'),
#  ('aflcio', 'attractive', 'angiotensin', 'addressed', '10_mm'),
#  ('afloat', 'attributed', 'angle', 'addresses', '10-mm'),
#  ('afoot', 'audience', 'angles', 'addressing', '10-month'),
#  ('aforementioned', 'audio', 'angluin', 'adecuado', '10-month-old'),
#  ('afoul', 'aug', 'angular', 'adelante', '10-mv'),
#  ('afp', 'august', 'animal', 'adelgid', '10nm'),
#  ('afpextel', 'austin', 'animation', 'ademas', '10-nm'),
#  ('afraid', 'australia', 'anism', 'adenovirus', '10p'),
#  ('africa', 'australian', 'anisotropic', 'adept', '10-point'),
#  ('africamiddle', 'author', 'anisotropy', 'adeptly', '10q'),
#  ('african', 'authorities', 'ann', 'adequacy', '10r'),
#  ('africanamerican', 'authority', 'anna', 'adequate', '10-residue'),
#  ('africas', 'authorization', 'annal', 'adequately', '10s'),
#  ('aft', 'authorize', 'annaswamy', 'adhere', '10-s'),
#  ('aftab', 'authorized', 'anneal', 'adhered', '10sa'),
#  ('afterhour', 'authors', 'annealed', 'adherence', '10-sec'),
#  ('aftermath', 'automated', 'annealing', 'adherent', '10/sec'),
#  ('afternoon', 'auxiliary', 'annotated', 'adheres', '10-second'),
#  ('afternoonevening', 'average', 'annu', 'adhering', '10-step'),
#  ('afterschool', 'avoid', 'annual', 'adhesion', '10t'),
#  ('aftertax', 'avoided', 'annular', 'adhesive', '1.0-t'),
#  ('afterthefact', 'avoiding', 'annulus', 'adhesives', '10th'),
#  ('afx', 'await', 'anomalous', 'adicional', '10-times'),
#  ('aga', 'awaiting', 'anomaly', 'adicionales', '10-week'),
#  ('agagu', 'award', 'anonymous', 'adieu', '10-week-old'),
#  ('against', 'awarded', 'anova', 'adios', '10-wk'),
#  ('agame', 'awards', 'ansatz', 'adj', '10-wk-old'),
#  ('agarwal', 'aware', 'answer', 'adjacent', '10x'),
#  ('agas', 'awareness', 'answered', 'adjective', '10-y'),
#  ('agc', 'awesome', 'ant', 'adjectives', '10_year'),
#  ('age', 'awful', 'antagonist', 'adjoin', '10-year'),
#  ('aged', 'awol', 'antagonistic', 'adjoining', '10-year-old'),
#  ('agence', 'axelrod', 'antecedent', 'adjourn', '10-yr'),
#  ('agencies', 'ayatollah', 'antenna', 'adjourned', '=11'),
#  ('agency', 'baathist', 'antennal', 'adjourning', '=.11'),
#  ('agenda', 'baby', 'antennas', 'adjournment', '>11'),
#  ('agendadoc', 'backed', 'anterior', 'adjudicate', '-1.1%'),
#  ('agendas', 'backers', 'anthony', 'adjudicated', '-11%'),
#  ('agent', 'background', 'anti', 'adjudicating', '.11'),
#  ('agerter', 'backing', 'anticipate', 'adjudication', '*1/*1'),
#  ('ages', 'backs', 'anticipated', 'adjudicator', '#11'),
#  ('agg', 'bad', 'anticipatory', 'adjunct', '+11%'),
#  ('aggie', 'badly', 'antisymmetric', 'adjust', '1.1-'),
#  ('aggies', 'baer', 'antlgen', 'adjustable', '1.1+'),
#  ('aggpwrii', 'bag', 'anton', 'adjusted', '11-'),
#  ('aggravate', 'baghdad', 'anu', 'adjuster', '11+'),
#  ('aggravated', 'baghdads', 'anyboost', 'adjusting', '110-'),
#  ('aggravation', 'bags', 'anymore', 'adjustment', '1100delc'),
#  ('aggregate', 'baker', 'anyway', 'adjutant', '110-fold'),
#  ('aggregated', 'balance', 'aperiodic', 'adman', '110k'),
#  ('aggregates', 'balanced', 'aperture', 'administer', '110-kd'),
#  ('aggregating', 'bald', 'apex', 'administered', '110-kda'),
#  ('aggregation', 'ball', 'apg', 'administering', '1,10-phenanthroline'),
#  ('aggregator', 'ballot', 'aphasia', 'administracion', '1/10th'),
#  ('aggressive', 'ballots', 'apical', 'administration', '11,12-'),
#  ('aggressively', 'ban', 'aplysia', 'administrative', '11,12-eet'),
#  ('aggrieved', 'band', 'apobayesian', 'administratively', '111in'),
#  ('agile', 'bandwagon', 'app', 'administrator', '111in-'),
#  ('agilent', 'bang', 'apparatus', 'adminstration', '111in-antimyosin'),
#  ('agility', 'bank', 'apparent', 'admirable', '111indium'),
#  ('agin', 'banking', 'apparently', 'admirably', '111indium-labeled'),
#  ('aging', 'banks', 'appeal', 'admiral', '111in-dtpa'),
#  ('agip', 'banned', 'appealing', 'admiration', '111in-dtpa-d-phe1-octreotide'),
#  ('agitation', 'banner', 'appearance', 'admire', '111in-dtpa-octreotide'),
#  ('agl', 'banning', 'appeared', 'admired', '111in-igg'),
#  ('aglc', 'bar', 'appearing', 'admirer', '111in-labeled'),
#  ('agnes', 'barack', 'appendix', 'admires', '111in-labelled'),
#  ('agnew', 'barbara', 'appl', 'admiring', '111in-octreotide'),
#  ('ago', 'barbero', 'apple', 'admiringly', '111in-oxine'),
#  ('agony', 'barbour', 'appli', 'admissibility', '111in-pentetreotide'),
#  ('agp', 'barely', 'applica', 'admissible', '111in-platelet'),
#  ('agr', 'barend', 'applicability', 'admission', '111-labeled'),
#  ('agra',
#   'bargaining',
#   'applicable',
#   'admit',
#   '1,1,1-trichloro-2,2-bisp-chlorophenylethane'),
#  ('agree', 'barnes', 'application', 'admite', '1,1,1-trichloroethane'),
#  ('agreeable',
#   'barrage',
#   'applied',
#   'admittance',
#   '1,1,2,2-tetrachloroethane'),
#  ('agreed', 'barrel', 'applies', 'admitted', '1,1,2-trichloroethane'),
#  ('agreeing', 'barrels', 'apply', 'admittedly', '1-13c'),
#  ('agreement', 'barrier', 'applying', 'admitting', '113cd'),
#  ('agreementdoc', 'barring', 'appreciable', 'admonish', '1-13cglucose'),
#  ('agrees', 'barry', 'appreciated', 'admonished', '1-13cleucine'),
#  ('agressive', 'bars', 'appro', 'admonishes', '113min'),
#  ('agricultural', 'bartlett', 'approach', 'admonishing', '1-14c'),
#  ('agriculture', 'base', 'approached', 'admonishment', '1-14c-'),
#  ('agrmt', 'baseball', 'approaches', 'admonition', '1-14cacetate'),
#  ('agt', 'based', 'approaching', 'adn', '1-14carachidonic'),
#  ('agua', 'baseline', 'appropri', 'ado', '1-14cglucose'),
#  ('aguirre', 'bases', 'appropriately', 'adobe', '1-14cleucine'),
#  ('aha', 'bashing', 'approx', 'adobo', '1-14coleate'),
#  ('ahanchian', 'basic', 'approxi', 'adolescence', '1-14coleic'),
#  ('ahead', 'basically', 'approxima', 'adolescent', '1-14cpalmitate'),
#  ('ahern', 'basis', 'approximate', 'adolescentes', '1-14cpalmitic'),
#  ('ahlstrom', 'basketball', 'approximated', 'adopt', '1-14cpyruvate'),
#  ('ahluwalia', 'basra', 'approximately', 'adopted', '115_b'),
#  ('ahmad', 'bastion', 'approximates', 'adoptee', '115-kda'),
#  ('ahman', 'batch', 'approximating', 'adoptees', '116-kda'),
#  ('ahmed', 'battalion', 'approximation', 'adopter', '119sn'),
#  ('ahn', 'battle', 'approximator', 'adopting', '11a'),
#  ('ahold', 'battlefield', 'apr', 'adoption', '11-amino'),
#  ('ahover', 'battleground', 'april', 'adoptive', '11-amino-acid'),
#  ('ahp', 'battlegrounds', 'apriori', 'adorable', '11b'),
#  ('aiaz', 'battles', 'aration', 'adorably', '11beta'),
#  ('aid', 'bay', 'arbi', 'adoration', '11betahsd'),
#  ('aida', 'bayh', 'arbib', 'adore', '11beta-hsd'),
#  ('aide', 'bbc', 'arbitrarily', 'adored', '11beta-hydroxylase'),
#  ('aided', 'beach', 'arbitrary', 'adores', '11beta-hydroxysteroid'),
#  ('aides', 'beacon', 'arbitration', 'adoring', '11-bp'),
#  ('aiding', 'bean', 'arbor', 'adoringly', '11c'),
#  ('aig', 'bear', 'arborization', 'adorn', '11c-acetate'),
#  ('aigerim', 'bears', 'arc', 'adorned', '11c-choline'),
#  ('aiken', 'beasley', 'arccos', 'adorning', '1-1cer'),
#  ('aikman', 'beat', 'arch', 'adornment', '11cflumazenil'),
#  ('ailcom', 'beaten', 'archi', 'adquirido', '11c-flumazenil'),
#  ('aileen', 'beating', 'archie', 'adquirio', '11-cis'),
#  ('ailing', 'beats', 'architec', 'adquirir', '11-cis-retinal'),
#  ('ailment', 'beauprez', 'architectural', 'adquirirse', '11-cis-retinol'),
#  ('aim', 'beautiful', 'architecture', 'adquisiciones', '11c-labeled'),
#  ('aimed', 'beauty', 'architectures', 'adr', '11c-labelled'),
#  ('aiming', 'bed', 'archive', 'adrenal', '11cmethionine'),
#  ('ain', 'beef', 'arcing', 'adrenalin', '11c-methionine'),
#  ('ainsworth', 'beer', 'ard', 'adrenaline', '11cmethyl'),
#  ('aint', 'beers', 'area', 'adrift', '11craclopride'),
#  ('air', 'began', 'areas', 'adroit', '11c-raclopride'),
#  ('airborne', 'begging', 'aren', 'adroitly', '11-day'),
#  ('aircard', 'begin', 'arethor', 'adulation', '11-day-old'),
#  ('airconditioner', 'beginning', 'arf', 'adult', '1,1-dce'),
#  ('airconditioning',
#   'begins',
#   'arg',
#   'adulterated',
#   '11-dehydrocorticosterone'),
#  ('aircraft', 'begun', 'argi', 'adulterating', '11-dehydrothromboxane'),
#  ('aired', 'behalf', 'argmax', 'adulteration', '11-dehydro-thromboxane'),
#  ('aires', 'behavior', 'argmaxp', 'adulterer', '11-deoxy'),
#  ('airfare', 'beheading', 'argmin', 'adulterous', '11-deoxycorticosterone'),
#  ('airfares', 'beings', 'argue', 'adultery', '11-deoxycortisol'),
#  ('airhotel', 'belief', 'argued', 'adulthood', '1,1-dichloroethylene'),
#  ('airing',
#   'beliefs',
#   'argues',
#   'adultos',
#   '1,1-dimethyl-4-phenylpiperazinium'),
#  ('airline',
#   'believed',
#   'argument',
#   'advance',
#   "1,1'-dioctadecyl-3,3,3',3'-tetramethylindocarbocyanine"),
#  ('airlineflight', 'believes', 'ariaboost', 'advanced', '1,1-dioxide'),
#  ('airliner',
#   'believing',
#   'aries',
#   'advancement',
#   '1,1-diphenyl-2-picrylhydrazyl'),
#  ('airlines', 'bell', 'arise', 'advancer', '11f'),
#  ('airmedia', 'belongs', 'arises', 'advances', '1.1-fold'),
#  ('airmiles', 'belt', 'arising', 'advancing', '11-fold'),
#  ('airplane', 'beltway', 'arithmetic', 'advantage', '11-gauge'),
#  ('airplanes', 'ben', 'arizona', 'advantaged', '11-hsd'),
#  ('airpollution', 'bench', 'arl', 'advantageous', '11-hydroxycorticosteroid'),
#  ('airport', 'beneath', 'arline', 'advantages', '11-hydroxylase'),
#  ('airportassessed', 'beneficiary', 'arm', 'advent', '11-item'),
#  ('airquality', 'benefit', 'arma', 'adventure', '11k'),
#  ('airtime', 'benefits', 'armed', 'adventurer', '1.1-kb'),
#  ('airtouch', 'bennett', 'armstrong', 'adventures', '11-kb'),
#  ('airtran', 'benson', 'army', 'adventuresome', '11-kda'),
#  ('airway', 'berg', 'arnold', 'adventurism', '11-keto'),
#  ('airwaysus', 'berger', 'aro', 'adventurous', '11-ketotestosterone'),
#  ('aisle', 'berkeley', 'arose', 'adventurousness', '11kt'),
#  ('ajay', 'bet', 'arousal', 'adverb', '11-kt'),
#  ('ajello', 'beth', 'arpa', 'adversarial', '11-mer'),
#  ('ajit', 'betrayal', 'arrange', 'adversaries', '11-mm'),
#  ('aka', 'betrayed', 'arranged', 'adversary', '11-month'),
#  ('akamai', 'betting', 'arrangement', 'adverse', '11-month-old'),
#  ('akara', 'bias', 'array', 'adversely', '11-ohc'),
#  ('aker', 'bible', 'arrhythmia', 'adversities', '11p'),
#  ('akili', 'bid', 'arrhythmias', 'adversity', '11-point'),
#  ('akin', 'biden', 'arrival', 'advertise', '11q'),
#  ('akron', 'bigger', 'arrive', 'advertised', '11q-'),
#  ('ala', 'biggest', 'arrived', 'advertisement', '11-residue'),
#  ('alabama', 'bill', 'arrives', 'advertiser', '11s'),
#  ('aladdin', 'billion', 'arriving', 'advertises', '11th'),
#  ('alaghband', 'billions', 'arrow', 'advertising', '11-week'),
#  ('alamac', 'billmon', 'art', 'advice', '11-week-old'),
#  ('alameda', 'bills', 'art1', 'advierte', '11-year'),
#  ('alamo', 'bin', 'art2', 'advisable', '11-year-old'),
#  ('alamodome', 'bio', 'artery', 'advise', '11-yr-old'),
#  ('alamos', 'biological', 'artex', 'advised', '=12'),
#  ('alan', 'bipartisan', 'arti', 'advisedly', '=.12'),
#  ('alarcon', 'bird', 'article', 'advisement', '>12'),
#  ('alarm', 'birth', 'articles', 'adviser', '-1.2%'),
#  ('alarmed', 'birthday', 'articulated', 'advises', '-12%'),
#  ('alarming', 'bishops', 'articulation', 'advising', '.12'),
#  ('alas', 'bit', 'articulator', 'advisor', '#12'),
#  ('alaska', 'bitch', 'articulatory', 'advisories', '+12%'),
#  ('alaskan', 'bite', 'artifact', 'advisory', '1,2-'),
#  ('alaskas', 'bits', 'artifactual', 'advocacy', '1/2-'),
#  ('alaywan', 'bitter', 'artifi', 'advocate', '1.2-'),
#  ('albania', 'bizarre', 'artificial', 'advocated', '1.2+'),
#  ('albanian', 'black', 'artificially', 'advocates', '12-'),
#  ('albany', 'blacks', 'artmap', 'advocating', '12+'),
#  ('albeit', 'blackwater', 'arx', 'aegis', '=120'),
#  ('albert', 'blackwell', 'ary', 'aeration', '>120'),
#  ('alberta', 'blades', 'asa', 'aerial', '120-'),
#  ('albertas', 'blair', 'ascender', 'aerialist', '1200-fold'),
#  ('alberto', 'blame', 'ascending', 'aerie', '120-day'),
#  ('albertson', 'blamed', 'ascent', 'aero', '120-day-old'),
#  ('albrecht', 'blames', 'ascertain', 'aerobatic', '120-fold'),
#  ('albright', 'blaming', 'ase', 'aerobic', '120-h'),
#  ('album', 'blanco', 'ash', 'aerodynamic', '120-hour'),
#  ('albuquerque', 'blank', 'asi', 'aerodynamically', '120k'),
#  ('alcantar', 'blast', 'asilomar', 'aerolinea', '120-kd'),
#  ('alcantara', 'blasted', 'ask', 'aerolineas', '120-kda'),
#  ('alcatel', 'blasting', 'asked', 'aeronautic', '120-min'),
#  ('alchemy', 'blatant', 'asking', 'aeronautical', '120/min'),
#  ('alcoa', 'bleak', 'asme', 'aeropuerto', '120-minute'),
#  ('alcohol',
#   'bleeding',
#   'asogawa',
#   'aeropuertos',
#   '12-0-tetradecanoyl-phorbol-13-acetate'),
#  ('alcosta',
#   'blessed',
#   'aspect',
#   'aerosol',
#   '12-0-tetradecanoylphorbol-13-acetate'),
#  ('alcove', 'blew', 'asr', 'aerospace', '120th'),
#  ('alden', 'blind', 'ass', 'aesthete', '12,13-dibutyrate'),
#  ('alder', 'blitz', 'assad', 'aesthetic', '12,13-didecanoate'),
#  ('aldine', 'blitzer', 'assembled', 'aesthetically', '12/15-lipoxygenase'),
#  ('aldrich', 'bloc', 'assembler', 'aesthetician', '12/15-lo'),
#  ('ale', 'block', 'assemblies', 'afan', '1,2,3,4-tetrahydroisoquinoline'),
#  ('alec', 'blocked', 'assembly', 'afar', '123i'),
#  ('aleck', 'blocks', 'assert', 'afc', '123ibeta-cit'),
#  ('alejandro', 'blog', 'assertion', 'afecta', '123i-bmipp'),
#  ('alert', 'blogads', 'assess', 'afectado', '123i-fp-cit'),
#  ('alerted', 'blogged', 'assessed', 'afecto', '123ifp-cit'),
#  ('alerting', 'blogger', 'assessing', 'affability', '123iibzm'),
#  ('alex', 'bloggers', 'assessment', 'affable', '123i-ibzm'),
#  ('alexa', 'blogging', 'asset', 'affair', '123i-imp'),
#  ('alexander', 'blogosphere', 'assign', 'affaires', '123i-imt'),
#  ('alexandra', 'blogpac', 'assigned', 'affect', '123i-iomazenil'),
#  ('alexandria', 'blogs', 'assigning', 'affectation', '123i-labeled'),
#  ('alexis', 'blood', 'assignment', 'affected', '123i-labelled'),
#  ('alfaisal',
#   'bloody',
#   'assimilation',
#   'affecting',
#   '123i-metaiodobenzylguanidine'),
#  ('alfalfa', 'bloomfield', 'assist', 'affectingly', '123imibg'),
#  ('alfio', 'blow', 'assistance', 'affection', '123i-mibg'),
#  ('alfred', 'blowing', 'assisted', 'affectionate', '1,2,4-benzenetriol'),
#  ('alfredo', 'blown', 'asso', 'affectionately', '124i'),
#  ('algebraic', 'blows', 'assoc', 'affective', '1,2,4-triazole'),
#  ('algeria', 'blue', 'associ', 'affidavit', '1,2,4-trichlorobenzene'),
#  ('algerian', 'bluff', 'associa', 'affiliate', '125-'),
#  ('algorithm', 'blunder', 'associate', 'affiliated', '1254-induced'),
#  ('alhambra', 'blunt', 'associates', 'affiliates', '1,25d'),
#  ('ali', 'board', 'associating', 'affiliation', '1,25-d'),
#  ('alice', 'boards', 'association', 'affiliative', '1,25-dhcc'),
#  ('alicia', 'boat', 'associative', 'affinities', '1,25-dihydroxy'),
#  ('alief', 'boats', 'associator', 'affinity', '1,25-dihydroxycholecalciferol'),
#  ('alien', 'bob', 'assp', 'affirm', '1,25-dihydroxyvitamin'),
#  ('alienate', 'bobby', 'assume', 'affirmation', '1,25-dihydroxy-vitamin'),
#  ('align',
#   'bode',
#   'assumed',
#   'affirmative',
#   '1-2,5-dimethoxy-4-iodophenyl-2-aminopropane'),
#  ('alignabsmiddle', 'bodies', 'assumes', 'affirmatively', '12.5-fold'),
#  ('aligncenter', 'body', 'assuming', 'affirmed', '125-fold'),
#  ('aligned', 'bogus', 'assump', 'affirming', '125i'),
#  ('aligning', 'bold', 'assumption', 'affix', '125-i'),
#  ('alignleft', 'bolster', 'assure', 'affixed', '125i-'),
#  ('alignment', 'bomb', 'assured', 'affixing', '125i-aii'),
#  ('alignright', 'bombing', 'assures', 'afflict', '125ialbumin'),
#  ('alike', 'bombings', 'ast', 'afflicted', '125i-albumin'),
#  ('alina', 'bombs', 'astc', 'afflicting', '125i-alpha'),
#  ('alinas', 'bombshell', 'asterisk', 'affliction', '125i-alpha-bungarotoxin'),
#  ('alink', 'bona', 'aston', 'affluence', '125ialpha-bungarotoxin'),
#  ('aliso', 'bond', 'astronomy', 'affluent', '125i-anf'),
#  ('alison', 'bonus', 'asy', 'afford', '125i-ang'),
#  ('alive', 'book', 'asymmetric', 'affordability', '125iangiotensin'),
#  ('alj', 'books', 'asymmetrical', 'affordable', '125i-angiotensin'),
#  ('alkane', 'boost', 'asymmetries', 'afforded', '125i-anp'),
#  ('alkaseltzer', 'boosted', 'asymmetry', 'affording', '125i-asor'),
#  ('allah', 'booth', 'asymp', 'affront', '125i-bfgf'),
#  ('allamerica', 'boots', 'asymptote', 'affronted', '125i-bolton-hunter'),
#  ('allamerican', 'bop', 'asymptotes', 'afghan', '125i-bovine'),
#  ('allan', 'border', 'asymptotic', 'afghani', '125i-bsa'),
#  ('allard', 'borders', 'asymptotically', 'afghanistan', '125i-c1q'),
#  ('allaround', 'boring', 'asynchronizable', 'aficionado', '125i-calmodulin'),
#  ('allay', 'born', 'asynchronous', 'aficionados', '125icgp'),
#  ('allbig', 'borrow', 'asynchronously', 'afield', '125icyanopindolol'),
#  ('allday', 'boss', 'ata', 'afire', '125i-cyanopindolol'),
#  ('alldistrict', 'boston', 'ate', 'afirma', '125icyp'),
#  ('allegany', 'bother', 'ated', 'afirman', '125iegf'),
#  ('allegation', 'bothered', 'ates', 'aflame', '125i-egf'),
#  ('allege', 'bottom', 'athe', 'aflatoxin', '125i-epidermal'),
#  ('alleged', 'bought', 'athena', 'afloat', '125i-factor'),
#  ('allegedly', 'boulder', 'ati', 'aflutter', '125i-fibrin'),
#  ('alleges', 'bounce', 'atick', 'afoot', '125i-fibrinogen'),
#  ('allegheny', 'bound', 'ating', 'aforementioned', '125i-fibronectin'),
#  ('allegiance', 'boundaries', 'ation', 'afoul', '125i-glucagon'),
#  ('alleging', 'bounds', 'ative', 'afraid', '125ihcg'),
#  ('allegis', 'bowers', 'atively', 'afresh', '125i-hcg'),
#  ('allegretti', 'bowerss', 'atiya', 'africa', '125i-hdl'),
#  ('allegro', 'bowl', 'atkeson', 'african', '125iheat'),
#  ('allemployee', 'bowles', 'atlanta', 'afrikaner', '125ihgh'),
#  ('allen', 'box', 'atlantic', 'afro', '125i-hgh'),
#  ('allende', 'boxblogroll', 'atlas', 'aft', '125i-hsa'),
#  ('allenhouect', 'boxer', 'atmospheric', 'afterburner', '125ihuman'),
#  ('allergy', 'boxfeed_listing', 'atom', 'aftercare', '125i-human'),
#  ('alleviate', 'boxrdf_feeds', 'atomic', 'aftereffect', '125i-igf-i'),
#  ('alley', 'boy', 'ator', 'afterglow', '125iigf-i'),
#  ('alliance', 'boycott', 'atr', 'afterlife', '125i-igf-ii'),
#  ('alliances', 'boys', 'att', 'aftermarket', '125iigf-ii'),
#  ('alliant', 'brad', 'attach', 'aftermath', '125i-igg'),
#  ('allied', 'bradley', 'attached', 'afternoon', '125iinsulin'),
#  ('allies', 'bradnickel', 'attachment', 'afterschool', '125i-insulin'),
#  ('alligator', 'brahimi', 'attack', 'aftershock', '125iiodocyanopindolol'),
#  ('allin', 'brain', 'attacked', 'aftertaste', '125i-iodocyanopindolol'),
#  ('allinclusive', 'branch', 'attain', 'afterthought', '125iiodoinsulin'),
#  ('allinone', 'branches', 'attainable', 'afterward', '125i-iothalamate'),
#  ('allison', 'brand', 'attained', 'afterword', '125i-labeled'),
#  ('allmystuff', 'braun', 'attaining', 'afuera', '125i-labelled'),
#  ('allnew', 'brave', 'attempt', 'agape', '125ildl'),
#  ('allocate', 'brazil', 'attempted', 'agar', '125i-ldl'),
#  ('allocated', 'break', 'attempting', 'agarcia', '125i-melatonin'),
#  ('allocates', 'breakdown', 'attend', 'agate', '125imibg'),
#  ('allocating', 'breakfast', 'attended', 'agatea', '125ingf'),
#  ('allocation', 'breaking', 'attention', 'agave', '125i-ngf'),
#  ('alloptic', 'breaks', 'attentional', 'age', '125iodine'),
#  ('allot', 'breath', 'attentive', 'aged', '125i-pdgf'),
#  ('allotment', 'breathtaking', 'attenuated', 'ageism', '125i-protein'),
#  ('allotted', 'breaux', 'attenuation', 'ageless', '125i-radiolabeled'),
#  ('allout', 'bremer', 'attias', 'agencia', '125i-tgf-beta'),
#  ('allowable', 'brian', 'attitude', 'agencias', '125i-thrombin'),
#  ('allowance', 'bridge', 'attrac', 'agencies', '125itid'),
#  ('allowances', 'bridges', 'attract', 'agency', '125i-transferrin'),
#  ('allowed', 'briefed', 'attracted', 'agenda', '125i-tsh'),
#  ('allowing', 'briefing', 'attracting', 'agendas', '125iudr'),
#  ('alloy', 'briefly', 'attraction', 'agent', '125ivip'),
#  ('allparty', 'brigade', 'attractive', 'agente', '125i-vip'),
#  ('allpurpose', 'brigades', 'attractor', 'agentes', '125-kda'),
#  ('allred', 'bright', 'attribute', 'ager', '125-labeled'),
#  ('allstar', 'brilliant', 'attributed', 'ages', '1,25oh2d'),
#  ('allstate', 'bring', 'attributes', 'agglomeration', '1,25-oh2d'),
#  ('allstock', 'bringing', 'ature', 'aggrandizement', '1,25-oh2-d'),
#  ('alltel', 'brings', 'atypical', 'aggrandizing', '1,25oh2d3-induced'),
#  ('alltime', 'brit', 'aud', 'aggravate', '1,25oh2d3-treated'),
#  ('alluded', 'britain', 'audio', 'aggravated', '1,25-oh2-vitamin'),
#  ('allure', 'british', 'audiovisual', 'aggravates', '1,25oh2-vitamin'),
#  ('alluring', 'brits', 'audition', 'aggravating', '127i'),
#  ('ally', 'broad', 'auditory', 'aggravation', '128-fold'),
#  ('alma', 'broadcast', 'auer', 'aggregate', '129i'),
#  ('almaden', 'broadcasting', 'aug', 'aggregated', '129/j'),
#  ('almaty', 'broader', 'augment', 'aggregates', '129sv'),
#  ('almeida', 'brock', 'augmentation', 'aggregating', '129/sv'),
#  ('almond', 'broder', 'augmented', 'aggregation', '129/svj'),
#  ('alnaimi', 'brokaw', 'augmenting', 'aggregator', '129xe'),
#  ('aloe', 'broke', 'august', 'aggression', '12a'),
#  ('aloha', 'broken', 'austin', 'aggressive', '1/2a'),
#  ('alongside', 'brokered', 'australia', 'aggressively', '12-amino'),
#  ('alonsozaldivar', 'bronze', 'australian', 'aggressiveness', '12b'),
#  ('alonzo', 'brooks', 'austria', 'aggressor', '1/2b'),
#  ('alot',
#   'brother',
#   'austrian',
#   'aggrieved',
#   "1,2-bis2-aminophenoxyethane-n,n,n',n'-tetraacetic"),
#  ('aloud',
#   'brothers',
#   'aut',
#   'aghast',
#   "1,2-biso-aminophenoxyethane-n,n,n',n'-tetraacetic"),
#  ('alp', 'brought', 'autapse', 'agile', '12-bit'),
#  ('alpert', 'broward', 'author', 'agility', '12-bp'),
#  ('alpertdavis', 'brown', 'autistic', 'aging', '12c'),
#  ('alpha', 'brownstein', 'auto', 'agitate', '1/2c'),
#  ('alphabetical',
#   'browser',
#   'autoassociation',
#   'agitated',
#   '1-2-chloroethyl-3-cyclohexyl-1-nitrosourea'),
#  ('alphanumeric', 'bruce', 'autoassociative', 'agitating', '12-cm'),
#  ('alpharetta', 'brush', 'autoassociator', 'agitation', '1,2-cyclic'),
#  ('alpine', 'brutal', 'autocorrelation', 'agitator', '1,2-cyclohexanedione'),
#  ('alqaeda', 'btw', 'autoencoder', 'agitprop', '12d'),
#  ('alquist', 'bubble', 'automata', 'aglass', '12-d'),
#  ('alright', 'buchanan', 'automate', 'aglow', '1,2-dag'),
#  ('alstom', 'buck', 'automated', 'agnellis', '12-day'),
#  ('alstott', 'bucks', 'automatic', 'agnostic', '12-day-old'),
#  ('alt', 'buddy', 'automatically', 'ago', '12-deoxyphorbol'),
#  ('alta', 'budget', 'automation', 'agog', '1,2-dg'),
#  ('altamira', 'budgets', 'automaton', 'agonies', '1,2-diacylglycerol'),
#  ('altar', 'bug', 'autonomous', 'agonize', '1,2-diacyl-sn-glycerol'),
#  ('altec', 'bugs', 'autonomously', 'agonized', '1,2-dibromo-3-chloropropane'),
#  ('alter', 'buh', 'autoregressive', 'agonizes', '1,2-dibromoethane'),
#  ('alteration',
#   'build',
#   'autorsm',
#   'agonizing',
#   '1,2-dichloro-4-nitrobenzene'),
#  ('altered', 'building', 'autoshaping', 'agonizingly', '1,2-dichlorobenzene'),
#  ('altering', 'buildings', 'autotypist', 'agony', '1,2-dichloroethane'),
#  ('alternate',
#   'built',
#   'aux',
#   'agoraphobia',
#   '1,2-dimethyl-3-hydroxypyrid-4-one'),
#  ('alternates', 'bulb', 'auxiliary', 'agordon', '12-dimethylbenzaanthracene'),
#  ('alternating', 'bulk', 'avail', 'agosto', '1,2-dimethylhydrazine'),
#  ('alternative',
#   'bullet',
#   'availability',
#   'agradable',
#   '1,2-dimethylhydrazine-induced'),
#  ('alternativeenergy',
#   'bullets',
#   'ave',
#   'agrarian',
#   '1,2-dimyristoyl-sn-glycero-3-phosphocholine'),
#  ('alternatively', 'bullshit', 'avenue', 'agree', '1,2-dioctanoylglycerol'),
#  ('alternatives', 'bully', 'aver', 'agreeable', '1,2-dioctanoyl-sn-glycerol'),
#  ('altman', 'bumblebums', 'average', 'agreeably', '1,2-diol'),
#  ('alto', 'bump', 'averaged', 'agreed', '1,2-dioxygenase'),
#  ('altobased',
#   'bumped',
#   'averages',
#   'agreeing',
#   '1,2-dipalmitoyl-sn-glycero-3-phosphocholine'),
#  ('altogether', 'bumper', 'averaging', 'agreement', '1,2-disubstituted'),
#  ('altos', 'bumpersticker', 'avg', 'agrees', '12f'),
#  ('altou', 'bunch', 'avi', 'agrega', '1.2-fold'),
#  ('altra', 'bunning', 'aviv', 'agri', '12-fold'),
#  ('alttop', 'bunnings', 'avlsi', 'agribusiness', '1-2gal'),
#  ('altura', 'burden', 'avn', 'agribusinesses', '1,2-gdn'),
#  ('alum', 'bureau', 'avoid', 'agricola', '12h'),
#  ('aluminium', 'bureaucratic', 'avoidance', 'agricolas', '12_h'),
#  ('aluminum', 'buried', 'avoided', 'agricultores', '12-h'),
#  ('alumni', 'burn', 'avoiding', 'agricultura', '12-hete'),
#  ('alumnijob', 'burned', 'awake', 'agricultural', '12-hour'),
#  ('alumnus', 'burning', 'award', 'agriculture', '12-hourly'),
#  ('alvarez', 'burns', 'aware', 'agro', '12-hpete'),
#  ('alvin', 'burr', 'awareness', 'agronomist', '12-hr'),
#  ('alwaleed',
#   'burt',
#   'awi',
#   'agronomy',
#   '12-hydroxy-5,8,10,14-eicosatetraenoic'),
#  ('alyson', 'bus', 'awij', 'aground', '12-hydroxyeicosatetraenoic'),
#  ('alzheimer', 'bush', 'awl', 'agua', '12-item'),
#  ('am100', 'bushcheney', 'awt', 'aguas', '12k'),
#  ('am1000', 'bushes', 'axe', 'aha', '1.2-kb'),
#  ('am1100', 'bushies', 'axes', 'ahead', '12-kb'),
#  ('am1200', 'bushkerry', 'axi', 'ahem', '12-kda'),
#  ('am700', 'bushrove', 'axial', 'ahh', '12l:12d'),
#  ('am930', 'bushs', 'axis', 'ahi', '12-lead'),
#  ('amabile', 'bushsux', 'axo', 'ahold', '12-lipoxygenase'),
#  ('amadeus', 'business', 'axon', 'ahora', '12-lo'),
#  ('amalgamated', 'businesses', 'axonal', 'aid', '12-lox'),
#  ('amanda', 'businessman', 'axt', 'aida', '12m'),
#  ('amani', 'bust', 'azimuth', 'aide', '1-2man'),
#  ('amar', 'busy', 'babak', 'aided', '12-membered'),
#  ('amarillo', 'button', 'bach', 'aides', '12-mer'),
#  ('amassed', 'buy', 'bachrach', 'aiding', '12-min'),
#  ('amassing', 'buying', 'bachtach', 'ail', '12-minute'),
#  ('amateur', 'buys', 'backbone', 'ailed', '1.2-mm'),
#  ('amaze', 'buzz', 'backer', 'aileron', '12-mm'),
#  ('amazed', 'buzzing', 'backfitting', 'ailing', '12-mo'),
#  ('amazing', 'bypass', 'backgammon', 'ailment', '12_month'),
#  ('amazingly', 'cabinet', 'background', 'aim', '12-month'),
#  ('amazon', 'cable', 'backprop', 'aimed', '1/2-month-old'),
#  ('amazoncom', 'caci', 'backpropa', 'aiming', '12-month-old'),
#  ('ambani', 'calculate', 'backpropaga', 'aimless', '12-mo-old'),
#  ('ambar', 'calculated', 'backpropagate', 'aimlessly', '12-myristate'),
#  ('ambassador',
#   'calculator',
#   'backpropagated',
#   'ain',
#   '12-myristate-13-acetate'),
#  ('amber', 'calendar', 'backpropagating', 'aioli', '1,2-naphthoquinone'),
#  ('ambev', 'california', 'backpropagation', 'air', '12-o-tetradecanoyl'),
#  ('ambient', 'calistan', 'backscatter', 'airbag', '12-o-tetradecanoylphorbol'),
#  ('ambiguities', 'call', 'backup', 'airball', '12-o-tetradecanoyl-phorbol'),
#  ('ambiguity',
#   'called',
#   'backward',
#   'airbase',
#   '12-o-tetradecanoyl-phorbol-13-acetate'),
#  ('ambiguous',
#   'calling',
#   'bad',
#   'airboat',
#   '12-o-tetradecanoylphorbol-13-acetate'),
#  ('ambition',
#   'calls',
#   'baddeley',
#   'airborne',
#   '12-o-tetradecanoylphorbol-13-acetate-induced'),
#  ('ambitious', 'calm', 'badly', 'airbrush', '12p'),
#  ('ambivalent', 'camejo', 'baep', 'airbrushed', '12-point'),
#  ('ambler', 'camera', 'bag', 'aircraft', '1,2-propanediol'),
#  ('ambulance', 'cameras', 'bagged', 'aircrew', '12q'),
#  ('amc', 'camp', 'bagging', 'airdrop', '12-residue'),
#  ('amclyde', 'campaign', 'bahl', 'aire', '12r-hete'),
#  ('amd', 'campaigned', 'bain', 'aired', '12s'),
#  ('amelia', 'campaigner', 'bair', 'airfare', '12-s'),
#  ('amen', 'campaigning', 'baird', 'airfares', '12s-hete'),
#  ('amenable', 'campaigns', 'baker', 'airfield', '12s-hydroxyeicosatetraenoic'),
#  ('amend', 'campbell', 'bakiri', 'airflow', '12-step'),
#  ('amended',
#   'camps',
#   'bakker',
#   'airframe',
#   '1-2-tetrahydrofuryl-5-fluorouracil'),
#  ('amending', 'campus', 'bal', 'airhead', '12th'),
#  ('amendment', 'canada', 'balance', 'airily', '12_week'),
#  ('amenities', 'canadian', 'balanced', 'airing', '12-week'),
#  ('amerada', 'canadians', 'balances', 'airless', '12-week-old'),
#  ('ameren', 'cancelled', 'balancing', 'airlift', '12-wk'),
#  ('amerex', 'cancer', 'baldi', 'airlifted', '12-wk-old'),
#  ('america', 'candidacy', 'ball', 'airlifting', '1/2-year'),
#  ('america_corp', 'candidate', 'ballard', 'airline', '12-year'),
#  ('americacanada', 'candidates', 'ballistic', 'airliner', '1/2-year-old'),
#  ('americaindustrial', 'canton', 'balltree', 'airlines', '12-year-old'),
#  ('american', 'cap', 'baltimore', 'airlock', '12-yr-old'),
#  ('americangreetingscom', 'capabilities', 'baluja', 'airmail', '=13'),
#  ('americas', 'capability', 'band', 'airman', '>13'),
#  ('amerindo', 'capable', 'bandit', 'airmen', '-13%'),
#  ('ameritech', 'capacity', 'bandpass', 'airplane', '.13'),
#  ('ameritrade', 'capital', 'bandwidth', 'airplanes', '*1/*3'),
#  ('amet', 'capitol', 'bang', 'airplay', '#13'),
#  ('amex', 'caps', 'bank', 'airport', '+13%'),
#  ('amfm', 'captain', 'bar', 'airpower', '1,3-'),
#  ('amgen', 'capture', 'barak', 'airship', '1.3-'),
#  ('ami', 'captured', 'baram', 'airspace', '13-'),
#  ('amicable', 'capturing', 'barbara', 'airspeed', '13+'),
#  ('amicably', 'car', 'barber', 'airstrike', '>130'),
#  ('amicus', 'carbon', 'barely', 'airstrikes', '130-'),
#  ('amid', 'card', 'barhen', 'airstrip', '130-fold'),
#  ('amidst', 'cards', 'bark', 'airtight', '130k'),
#  ('amie', 'care', 'barkai', 'airtime', '130-kd'),
#  ('amigo', 'career', 'barlow', 'airwave', '130-kda'),
#  ('amir', 'careful', 'barn', 'airwaves', '13,14-dihydro-15-keto'),
#  ('amirault',
#   'carefully',
#   'barnard',
#   'airway',
#   '13,14-dihydro-15-keto-prostaglandin'),
#  ('amit', 'cares', 'barnden', 'airworthiness', '131i'),
#  ('amita', 'cargo', 'barnes', 'airy', '131-i'),
#  ('ammar', 'carl', 'barney', 'aisle', '131i-'),
#  ('ammiano', 'carlos', 'baroque', 'aisles', '131i-albumin'),
#  ('ammunition', 'carlson', 'barr', 'aja', '131i-hippuran'),
#  ('amnesty', 'carol', 'barrel', 'ajar', '131i-labeled'),
#  ('amoco', 'carolina', 'barrett', 'ajc', '131i-labelled'),
#  ('amok', 'carried', 'barrier', 'aka', '131i-lipiodol'),
#  ('amortization',
#   'carrier',
#   'barron',
#   'akimbo',
#   '131i-metaiodobenzylguanidine'),
#  ('amortize', 'carries', 'barrow', 'akin', '131imibg'),
#  ('amortized', 'carry', 'barry', 'akornblut', '131i-mibg'),
#  ('amory', 'carrying', 'bart', 'ala', '131i-oih'),
#  ('amos', 'cars', 'bartlett', 'alabama', '133c'),
#  ('amount', 'carson', 'barto', 'alabaster', '133xe'),
#  ('amounted', 'carsons', 'barycentric', 'alacrity', '133xenon'),
#  ('amounting', 'carter', 'basal', 'aladdin', '133-xenon'),
#  ('amp', 'carville', 'base', 'alai', '1,3,4,5-tetrakisphosphate'),
#  ('ampersand', 'cases', 'baseband', 'alan', '134a'),
#  ('ample', 'cash', 'baseline', 'alarm', '134c'),
#  ('amplification', 'cast', 'bases', 'alarmed', '1,3,4-trisphosphate'),
#  ('amplified', 'castor', 'basford', 'alarming', '135-kda'),
#  ('amplifier', 'castro', 'basic', 'alarmingly', '13762nf'),
#  ('amr', 'casts', 'basically', 'alarmist', '137c'),
#  ('amrn', 'casualties', 'basilar', 'alas', '13a'),
#  ('amro', 'casualty', 'basin', 'alaska', '13-acetate'),
#  ('amsterdam', 'cat', 'basis', 'alaskan', '13-acetate-induced'),
#  ('amt', 'catch', 'basri', 'albacore', '13-amino'),
#  ('amusement', 'catching', 'bass', 'albanian', '13b'),
#  ('amusing', 'categories', 'bastian', 'albany', '1-->3-beta-d-glucan'),
#  ('amw', 'category', 'bat', 'albatross', '1----3-beta-d-glucan'),
#  ('amy', 'catholic', 'batch', 'albatrosses', '1,3-beta-d-glucan'),
#  ('ana', 'catholics', 'batches', 'albeit', '1,3-beta-glucan'),
#  ('anadarko', 'cato', 'bateson', 'albert', '1,3-beta-glucanase'),
#  ('anaheim', 'cats', 'bath', 'albino', '1,3-bis-2-chloroethyl-1-nitrosourea'),
#  ('anahuac',
#   'cattle',
#   'batteries',
#   'albright',
#   '1,3-bis2-chloroethyl-1-nitrosourea'),
#  ('analog', 'caucus', 'battery', 'album', '13-bp'),
#  ('analogies', 'caucuses', 'battiti', 'alcanzar', '1,3-butadiene'),
#  ('analogous', 'caucusgoers', 'bauer', 'alchemist', '1,3-butanediol'),
#  ('analogy', 'caught', 'baum', 'alchemy', '13c'),
#  ('analyse', 'caused', 'baxter', 'alcogel', '13c-'),
#  ('analyses', 'causing', 'bay', 'alcohol', '13c/12c'),
#  ('analysis', 'caution', 'bayes', 'alcoholic', '13c-13c'),
#  ('analysis_____________________',
#   'cautious',
#   'bayesian',
#   'alcoholism',
#   '13c-1h'),
#  ('analyst', 'caveats', 'bayliss', 'alcove', '13calpha'),
#  ('analystassociate', 'cbs', 'baylor', 'alcoves', '13c-enriched'),
#  ('analystresearcher', 'cegelis', 'bbd', 'aldea', '13c-enrichment'),
#  ('analytic', 'ceiling', 'bbn', 'alder', '13cglucose'),
#  ('analytical', 'celebrate', 'bbp', 'alderman', '13-cis'),
#  ('analyze', 'celebration', 'bcm', 'ale', '13-cis-'),
#  ('analyzed', 'celebrity', 'bdcl', 'aleck', '13-cis-ra'),
#  ('analyzer', 'cell', 'bdg', 'alecky', '13-cis-retinoic'),
#  ('analyzes', 'cells', 'bdgptk', 'aleman', '13c-labeled'),
#  ('analyzing', 'censure', 'bead', 'alert', '13c-labeling'),
#  ('anand', 'census', 'beam', 'alerted', '13c-labelled'),
#  ('anathema', 'cent', 'bear', 'alerting', '13cleucine'),
#  ('anatol', 'center', 'bearing', 'alertly', '13cnmr'),
#  ('ancestrycom', 'centers', 'beat', 'alertness', '13c-nmr'),
#  ('anchor', 'central', 'beaverton', 'ales', '13c-n.m.r'),
#  ('anchorage', 'centrist', 'beck', 'alevine', '13c-nuclear'),
#  ('anchordesk', 'cents', 'becker', 'alex', '13co'),
#  ('anchored', 'century', 'beckman', 'alexander', '13c-octanoic'),
#  ('ancient', 'ceo', 'bed', 'alexandria', '13cra'),
#  ('ancillary', 'ceremony', 'bee', 'alfalfa', '13-cra'),
#  ('andal', 'cfr', 'beer', 'alfred', '13c-ubt'),
#  ('andaman', 'chafee', 'bees', 'alfresco', '13curea'),
#  ('andand', 'chain', 'began', 'algae', '13c-urea'),
#  ('andell', 'chair', 'begin', 'algal', '1,3-d'),
#  ('ander', 'chairman', 'beginning', 'algebra', '13-day'),
#  ('andersen', 'chairs', 'begun', 'algebraic', '13-day-old'),
#  ('anderson', 'chalabi', 'behav', 'algo', '1,3-diaminopropane'),
#  ('andes', 'chalabis', 'behave', 'algore2000', '13-dibutyrate'),
#  ('andhra', 'challenge', 'behaved', 'algorithm', '1,3-dichloropropene'),
#  ('andor', 'challenged', 'behaves', 'alguien', '1,3-dienes'),
#  ('andover', 'challenger', 'behaving', 'algun', '1,3-dimethyluric'),
#  ('andre', 'challengers', 'behavior', 'alguna', '1,3-dinitrobenzene'),
#  ('andrea', 'challenges', 'behavioral', 'algunas', '1,3-dipolar'),
#  ('andreas',
#   'challenging',
#   'behaviorally',
#   'alguno',
#   '1,3-dipropyl-8-cyclopentylxanthine'),
#  ('andres', 'chamber', 'behaviour', 'algunos', '1,3-dnb'),
#  ('andrew', 'chambers', 'behavioural', 'ali', '1.3-fold'),
#  ('andy', 'chambliss', 'behrmann', 'alianza', '13-fold'),
#  ('anecdotal', 'chance', 'belew', 'alianzas', '1-3gal'),
#  ('anecdotes', 'chances', 'belgium', 'alias', '1----3gal'),
#  ('aneela', 'chandler', 'belief', 'aliases', '1-3galnac'),
#  ('anemia', 'chandlers', 'believe', 'alibi', '1,3galnac'),
#  ('anemic', 'change', 'believed', 'alibis', '1,3-gdn'),
#  ...]
